# %% [markdown]
# <a href="https://colab.research.google.com/github/AnkitSharma-29/Projects/blob/main/housing_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -*- coding: utf-8 -*-
"""Welcome To Colab

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/notebooks/intro.ipynb

**HOUSING DATA ANALYSIS**


---
"""

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load the dataset into a pandas DataFrame called Housing.
# Make sure to replace 'Housing.csv' with the actual path to your file if it's not in the same directory
Housing = pd.read_csv('Housing.csv')

# Summary statistics of the dataset
summary_stats = Housing.describe()

# Visualize the distribution of house prices
plt.figure(figsize=(8,6))
sns.histplot(Housing['price'], kde=True, color='blue') # Access the price column using Housing['price']
plt.title('Distribution of House Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

summary_stats

import pandas as pd

# Correct the file path to the actual location of your Housing.csv file
# For example, if the file is in the current directory:
file_path = 'Housing.csv'
# Or if it's in a specific folder like 'data':
# file_path = 'data/Housing.csv'
# Or if it is in the /mnt/data location make sure the file exists there
# and is accessible to the notebook user
# file_path = '/mnt/data/Housing.csv'

housing_data = pd.read_csv(file_path)

# Display the first few rows of the dataset
housing_data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished
